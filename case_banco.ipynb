# %% [markdown]
# <a href="https://colab.research.google.com/github/caiom26/AnaliseDeDados/blob/main/case_banco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('/content/BankChurners.csv')
df2=pd.read_excel('/content/metadados.xlsx')

# %%
df1.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df1.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',axis=1)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df1['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df2.tail(22)
# Out:
#                                               Colunas  \
# 1                                      Attrition_Flag
# 2                                        Customer_Age
# 3                                              Gender
# 4                                     Dependent_count
# 5                                     Education_Level
# 6                                      Marital_Status
# 7                                     Income_Category
# 8                                       Card_Category
# 9                                      Months_on_book
# 10                           Total_Relationship_Count
# 11                             Months_Inactive_12_mon
# 12                              Contacts_Count_12_mon
# 13                                       Credit_Limit
# 14                                Total_Revolving_Bal
# 15                                    Avg_Open_To_Buy
# 16                               Total_Amt_Chng_Q4_Q1
# ...

# %%
df1=df1.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',axis=1)

# %%
df1=df1.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',axis=1)

# %%
df1.set_index('CLIENTNUM',inplace=True)

# %%
df1.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# ...

# %%
num_col = df1.select_dtypes(include=['number']).columns
obj_col = df1.select_dtypes(include=['object']).columns

# %%
print(obj_col)
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category'],
#       dtype='object')

# %%
df1.index.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# !pip install ipywidgets
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.8 MB/s eta 0:00:00
# ...

# %%
def plot_boxplot(coluna):
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df1, y=coluna)
    plt.title(f'Boxplot de {coluna}')
    plt.show()

# %%
contagem_attrition = df1.groupby('Attrition_Flag')['Attrition_Flag'].count().reset_index(name='count')
plt.figure(figsize=(8, 6))
sns.barplot(data=contagem_attrition, x='Attrition_Flag', y='count', palette='Blues')
# Out:
# <ipython-input-22-0e3fc9deb1a7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=contagem_attrition, x='Attrition_Flag', y='count', palette='Blues')
# <Axes: xlabel='Attrition_Flag', ylabel='count'>

# %%
@interact(plot_boxplot, coluna=num_col)
def plot_boxplot(coluna):
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df1, y=coluna)
    plt.title(f'Boxplot de {coluna}')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='coluna', options=('Customer_Age', 'Dependent_count', 'Months_on_bo…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-38411eaf0ec7> in <cell line: 1>()
#       1 @interact(plot_boxplot, coluna=num_col)
# ----> 2 def plot_boxplot(coluna):
#       3     plt.figure(figsize=(8, 6))
#       4     sns.boxplot(data=df1, y=coluna)
#       5     plt.title(f'Boxplot de {coluna}')
#
# <ipython-input-17-0f05df3dfe4a> in plot_boxplot(coluna)
#       1 def plot_boxplot(coluna):
#       2     plt.figure(figsize=(8, 6))
# ----> 3     sns.boxplot(data=df1, y=coluna)
#       4     plt.title(f'Boxplot de {coluna}')
#       5     plt.show()
#
# ...

# %%
df1.groupby('Attrition_Flag')['Attrition_Flag'].count()
# Out:
# Attrition_Flag
# Attrited Customer    1627
# Existing Customer    8500
# Name: Attrition_Flag, dtype: int64

# %%
import seaborn as sns
from ipywidgets import interact

# %%
def count_outliers(df, coluna):

    Q1 = df[coluna].quantile(0.25)
    Q3 = df[coluna].quantile(0.75)


    IQR = Q3 - Q1


    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR


    outliers = df[(df[coluna] < limite_inferior) | (df[coluna] > limite_superior)]

    return len(outliers)

# %%
for col in num_col:
    outliers_count = count_outliers(df1, col)
    print(f"Número de outliers em {col}: {outliers_count}")
# Out:
# Número de outliers em Customer_Age: 2
# Número de outliers em Dependent_count: 0
# Número de outliers em Months_on_book: 386
# Número de outliers em Total_Relationship_Count: 0
# Número de outliers em Months_Inactive_12_mon: 331
# Número de outliers em Contacts_Count_12_mon: 629
# Número de outliers em Credit_Limit: 984
# Número de outliers em Total_Revolving_Bal: 0
# Número de outliers em Avg_Open_To_Buy: 963
# Número de outliers em Total_Amt_Chng_Q4_Q1: 396
# Número de outliers em Total_Trans_Amt: 896
# Número de outliers em Total_Trans_Ct: 2
# Número de outliers em Total_Ct_Chng_Q4_Q1: 394
# Número de outliers em Avg_Utilization_Ratio: 0

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df1.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# ...

# %%
df1['Credit_Limit']=df1['Credit_Limit']

# %%
#Não faz sentido falar em outliers quando se trata de Meses em contrato, Meses em inatividade e contagem de contatos.
#Nas demais colunas com outliers superiores a 100 aplicaremos a função log para redução dos outliers

# %%
cols_para_log=['Credit_Limit','Avg_Open_To_Buy','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt','Total_Ct_Chng_Q4_Q1']

# %%
scaler=StandardScaler()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
epsilon = 1e-6

for cols in cols_para_log:
    df1[cols] = np.log1p(df1[cols].replace(0, epsilon))
#Optou-se por esse procedimento para evitar o log de zero.
df1.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# ...

# %%
df1=remove_outliers(df1,'Credit_Limit')
df1.head()
#Agora removemos os outliers
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# ...

# %%
for col in num_col:
    outliers_count = count_outliers(df1, col)
    print(f"Número de outliers em {col}: {outliers_count}")
# Out:
# Número de outliers em Customer_Age: 2
# Número de outliers em Dependent_count: 0
# Número de outliers em Months_on_book: 386
# Número de outliers em Total_Relationship_Count: 0
# Número de outliers em Months_Inactive_12_mon: 331
# Número de outliers em Contacts_Count_12_mon: 629
# Número de outliers em Credit_Limit: 0
# Número de outliers em Total_Revolving_Bal: 0
# Número de outliers em Avg_Open_To_Buy: 21
# Número de outliers em Total_Amt_Chng_Q4_Q1: 378
# Número de outliers em Total_Trans_Amt: 191
# Número de outliers em Total_Trans_Ct: 2
# Número de outliers em Total_Ct_Chng_Q4_Q1: 419
# Número de outliers em Avg_Utilization_Ratio: 0

# %%
for col in num_col:
    while True:
        outliers_count = count_outliers(df1, col)
        if outliers_count > 100:
            df1 = remove_outliers(df1, col)
        else:
            break

# %%
def contagem_de_outliers():
  for col in num_col:
    outliers_count = count_outliers(df1, col)
    print(f"Número de outliers em {col}: {outliers_count}")

# %%
df1=remove_outliers(df1,'Total_Trans_Amt')

# %%
contagem_de_outliers()
#Contamos os outliers
# Out:
# Número de outliers em Customer_Age: 1
# Número de outliers em Dependent_count: 866
# Número de outliers em Months_on_book: 0
# Número de outliers em Total_Relationship_Count: 0
# Número de outliers em Months_Inactive_12_mon: 0
# Número de outliers em Contacts_Count_12_mon: 0
# Número de outliers em Credit_Limit: 0
# Número de outliers em Total_Revolving_Bal: 0
# Número de outliers em Avg_Open_To_Buy: 13
# Número de outliers em Total_Amt_Chng_Q4_Q1: 28
# Número de outliers em Total_Trans_Amt: 57
# Número de outliers em Total_Trans_Ct: 5
# Número de outliers em Total_Ct_Chng_Q4_Q1: 21
# Número de outliers em Avg_Utilization_Ratio: 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7541 entries, 708790833 to 714337233
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            7541 non-null   object
#  1   Customer_Age              7541 non-null   int64
#  2   Gender                    7541 non-null   object
#  3   Dependent_count           7541 non-null   int64
#  4   Education_Level           7541 non-null   object
#  5   Marital_Status            7541 non-null   object
#  6   Income_Category           7541 non-null   object
#  7   Card_Category             7541 non-null   object
#  8   Months_on_book            7541 non-null   int64
#  9   Total_Relationship_Count  7541 non-null   int64
#  10  Months_Inactive_12_mon    7541 non-null   int64
#  11  Contacts_Count_12_mon     7541 non-null   int64
#  12  Credit_Limit              7541 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for cols in obj_col:
    le=LabelEncoder()
    df1[cols]=le.fit_transform(df1[cols])
#Tratamos agora os Dados Categóricos
df1.head()
# Out:
#            Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# CLIENTNUM
# 708790833               1            42       1                5
# 712396908               1            57       0                2
# 709327383               1            45       0                2
# 811604133               1            47       0                4
# 789124683               1            54       1                2
#
#            Education_Level  Marital_Status  Income_Category  Card_Category  \
# CLIENTNUM
# 708790833                5               3                0              0
# 712396908                2               1                4              0
# 709327383                2               1                5              0
# 811604133                6               2                4              0
# 789124683                6               1                3              0
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
#Agora iremos treinar o modelo

y=df1['Attrition_Flag']
X=df1.drop('Attrition_Flag',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=60)

# %%
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train_smote,y_train_smote)
# Out:
# RandomForestClassifier()

# %%
#Determinamos a importância de cada variável para a deixada do cliente
importance = model.feature_importances_
for i,v in enumerate(importance):
    print(f'Feature: {X.columns[i]}, Score: {v}')
# Out:
# Feature: Customer_Age, Score: 0.024412630185794783
# Feature: Gender, Score: 0.03237968292290074
# Feature: Dependent_count, Score: 0.010251306640021487
# Feature: Education_Level, Score: 0.009870729014270973
# Feature: Marital_Status, Score: 0.0070502293271967505
# Feature: Income_Category, Score: 0.016359200515746936
# Feature: Card_Category, Score: 0.002810876059167763
# Feature: Months_on_book, Score: 0.016489115102731388
# Feature: Total_Relationship_Count, Score: 0.05208633688303008
# Feature: Months_Inactive_12_mon, Score: 0.031394329177253696
# Feature: Contacts_Count_12_mon, Score: 0.009902202084225415
# Feature: Credit_Limit, Score: 0.029437364937453792
# Feature: Total_Revolving_Bal, Score: 0.10096800934574339
# Feature: Avg_Open_To_Buy, Score: 0.029140163703742044
# Feature: Total_Amt_Chng_Q4_Q1, Score: 0.04272827709413234
# Feature: Total_Trans_Amt, Score: 0.2207134291955773
# Feature: Total_Trans_Ct, Score: 0.24201237131904557
# ...

# %%
features=[]
scores=[]


for i, v in enumerate(importance):
    features.append(X.columns[i])
    scores.append(v)
feature_importance_df = pd.DataFrame({
    'Feature': features,
    'Score': scores
})

feature_importance_df.head()
#Criamos um DF com as informações
# Out:
#            Feature     Score
# 0     Customer_Age  0.032442
# 1           Gender  0.009281
# 2  Dependent_count  0.013924
# 3  Education_Level  0.012425
# 4   Marital_Status  0.009467

# %%
feature_importance_df.sort_values(by='Score',ascending=False,inplace=True)
#Ordenamos por ordem de importância

# %%
feature_importance_df.head(6)
# Out:
#                      Feature     Score
# 15           Total_Trans_Amt  0.218081
# 16            Total_Trans_Ct  0.179596
# 12       Total_Revolving_Bal  0.111633
# 17       Total_Ct_Chng_Q4_Q1  0.089683
# 8   Total_Relationship_Count  0.058367
# 14      Total_Amt_Chng_Q4_Q1  0.055080

# %%
y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)[:, 1]

# %%
print("Acurácia:", accuracy_score(y_test, y_pred))
print("Precisão:", precision_score(y_test, y_pred))
print("Revocação:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("\nRelatório de Classificação:\n", classification_report(y_test, y_pred))
# Out:
# Acurácia: 0.9549270879363676
# Precisão: 0.9797225186766275
# Revocação: 0.9663157894736842
# F1 Score: 0.972972972972973
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.84      0.90      0.86       363
#            1       0.98      0.97      0.97      1900
#
#     accuracy                           0.95      2263
#    macro avg       0.91      0.93      0.92      2263
# weighted avg       0.96      0.95      0.96      2263

# %%
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, classification_report

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nMatriz de Confusão:\n", conf_matrix)
# Out:
# Matriz de Confusão:
#  [[ 325   38]
#  [  64 1836]]

# %%
plt.figure(figsize=(6,6))
plt.imshow(conf_matrix, cmap=plt.cm.Blues)
plt.title("Matriz de Confusão")
plt.colorbar()
plt.xlabel("Classe Predita")
plt.ylabel("Classe Verdadeira")
plt.xticks(np.arange(len(model.classes_)), model.classes_)
plt.yticks(np.arange(len(model.classes_)), model.classes_)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos')
plt.ylabel('Taxa de Verdadeiros Positivos')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
